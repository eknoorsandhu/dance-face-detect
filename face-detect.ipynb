# %%
from mtcnn import MTCNN
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('capture.jpg', cv2.IMREAD_COLOR)
detector = MTCNN()
json = detector.detect_faces(img)
json
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# [{'box': [384, 69, 320, 403],
#   'confidence': 0.9998192191123962,
#   'keypoints': {'left_eye': (492, 243),
#    'right_eye': (640, 251),
#    'nose': (570, 346),
#    'mouth_left': (493, 403),
#    'mouth_right': (614, 408)}}]

# %%
plt.imshow(img)

# %%
# plot the bounding box
x, y, width, height = json[0]["box"]
cv2.rectangle(img, (x, y), (x + width, y + height), (255, 0, 0), 2)
plt.imshow(img)
